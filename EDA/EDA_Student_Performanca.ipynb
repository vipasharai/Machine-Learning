# %% [markdown]
# # Student Performance

# %% [raw]
# The dataset is related to student performance and attributes in secondary education. Here's a general introduction based on the columns present in the DataFrame:
#
# This dataset contains information about students in secondary education, including demographic details, family background, educational support, lifestyle choices, and academic performance. Each row represents a unique student, and the columns provide various attributes and characteristics associated with them.

# %% [raw]
# Dataset contains following columns:
# school: School attended by the student.
# sex: Student's gender (male or female).
# age: Student's age.
# address: Type of address of the student (urban or rural).
# famsize: Family size (binary categorization: "LE3" - less or equal to 3 or "GT3" - greater than 3).
# Pstatus: Parent's cohabitation status (living together or apart).
# Medu: Mother's education level (0 to 4, representing none to higher education).
# Fedu: Father's education level (0 to 4, representing none to higher education).
# Mjob: Mother's occupation.
# Fjob: Father's occupation.
# reason: Reason for choosing the school.
# guardian: Student's guardian.
# traveltime: Travel time to school.
# studytime: Weekly study time (hours).
# failures: Number of past class failures.
# schoolsup: Extra educational support at school (yes or no).
# famsup: Family educational support (yes or no).
# paid: Extra paid classes within the course subject (yes or no).
# activities: Extra-curricular activities (yes or no).
# nursery: Attended nursery school (yes or no).
# higher: Wants to take higher education (yes or no).
# internet: Internet access at home (yes or no).
# romantic: In a romantic relationship (yes or no).
# famrel: Quality of family relationships (from 1 - very bad to 5 - excellent).
# freetime: Free time after school (from 1 - very low to 5 - very high).
# goout: Going out with friends (from 1 - very low to 5 - very high).
# Dalc: Workday alcohol consumption (from 1 - very low to 5 - very high).
# Walc: Weekend alcohol consumption (from 1 - very low to 5 - very high).
# health: Current health status (from 1 - very bad to 5 - very good).
# absences: Number of school absences.
# G1: First period grade (from 0 to 20).
# G2: Second period grade (from 0 to 20).
# G3: Final grade (from 0 to 20).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("student-por.csv")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        4   0  11  11
# 1    ...      5        3      3     1     1      3        2   9  11  11
# 2    ...      4        3      2     2     3      3        6  12  13  12
# 3    ...      3        2      2     1     1      5        0  14  14  14
# 4    ...      4        3      2     1     2      5        0  11  13  13
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [649 rows x 33 columns]

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (649, 33)

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# std      0.955717    1.051093    1.175766    0.924834    1.284380    1.446259
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    2.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  649.000000  649.000000  649.000000  649.000000
# mean     3.659476   11.399076   11.570108   11.906009
# std      4.640759    2.745265    2.913639    3.230656
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   10.000000   10.000000   10.000000
# 50%      2.000000   11.000000   11.000000   12.000000
# 75%      6.000000   13.000000   13.000000   14.000000
# max     32.000000   19.000000   19.000000   19.000000

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
# Insights -- There are no null values in the dataset

# %% [markdown]
# ## Univariate analysis

# %%
df['school'].value_counts()
# Out:
# school
# GP    423
# MS    226
# Name: count, dtype: int64

# %%
df['school'].value_counts(normalize=True) # percentile
# Out:
# school
# GP    0.651772
# MS    0.348228
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='school',data=df,palette='pastel')
plt.title('Distribution of schools')
plt.xlabel("School")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [raw]
# # Insights -- GP has higher no. of students .

# %% [markdown]
# ## Histogram

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
sns.histplot(df['age'], bins=10,kde=True, palette='pastel')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [raw]
# # Insights-- Most of the students are in the age group 16-17 -- Skewed distribution

# %%
sns.countplot(x='address', data=df, palette='dark')
# Out:
# <Axes: xlabel='address', ylabel='count'>

# %% [raw]
# # The majority of students comes from urban region

# %%
df['reason'].unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
df['reason'].value_counts()
# Out:
# reason
# course        285
# home          149
# reputation    143
# other          72
# Name: count, dtype: int64

# %% [markdown]
# ## Pie chart

# %%
reason=df['reason'].value_counts()
plt.pie(reason, labels=reason.index, autopct='%1.1f%%')
plt.show()

# %% [raw]
# # Insights-- common reason - to join the course

# %%
df.activities
# Out:
# 0       no
# 1       no
# 2       no
# 3      yes
# 4       no
#       ...
# 644    yes
# 645     no
# 646    yes
# 647     no
# 648     no
# Name: activities, Length: 649, dtype: object

# %%
act=df['activities'].value_counts()
plt.pie(act, labels=act.index, autopct='%1.1f%%')
plt.show()

# %% [raw]
# # 48.5% are participating

# %%
df['Walc'].value_counts()
# Out:
# Walc
# 1    247
# 2    150
# 3    120
# 4     87
# 5     45
# Name: count, dtype: int64

# %%
w=df['Walc'].value_counts()
plt.pie(w, labels=w.index, autopct='%1.1f%%')
plt.show()

# %% [raw]
# # Insights-- 45 students have regular weekend alcohol consumption

# %%
df['Dalc'].value_counts()
# Out:
# Dalc
# 1    451
# 2    121
# 3     43
# 5     17
# 4     17
# Name: count, dtype: int64

# %% [raw]
# # Insighs -17 sudents have reugular daily alcohol consumption

# %% [raw]
# # Pie chart

# %%
D=df['Dalc'].value_counts()
plt.pie(D, labels=D.index, autopct='%1.1f%%')
plt.show()

# %% [raw]
# # Insights-- 2.6%  students are consuming alcohol in daily bases

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(x='Medu',data=df,palette='Set2')
plt.xlabel("Mother education label")
plt.ylabel("count")
plt.title("Mother Education Level dist")


plt.subplot(1,2,2)
sns.countplot(x='Fedu',data=df,palette='Set2')
plt.xlabel("Father education label")
plt.ylabel("count")
plt.title("father Education Level dist")

plt.show()

# %% [raw]
# # Insights -- Mothers are more educated in terms of higher education as compared to father

# %%
sns.barplot(x='studytime', y='G3', data=df, palette='muted')
# Out:
# <Axes: xlabel='studytime', ylabel='G3'>

# %% [raw]
# # Insights --  if a student study  study for an hour than the marks score  on an average is 11
# # if a student study  study for two hour than the marks score  on an average is 11
# -- y axis represent avg marks

# %%
df.G3.unique()
# Out:
# array([11, 12, 14, 13, 17, 15,  7, 10, 16,  9,  8, 18,  6,  0,  1,  5, 19])

# %%
sns.barplot(x='studytime', y='G2', data=df, palette='muted')
# Out:
# <Axes: xlabel='studytime', ylabel='G2'>

# %%
sns.barplot(x='internet', y='G3', data=df, palette='pastel')
# Out:
# <Axes: xlabel='internet', ylabel='G3'>

# %% [raw]
# # Insights -- on an avg students using internet is getting a score of 12

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.barplot(x='sex',y='G3', hue='address', data=df, palette='Set2')
# Out:
# <Axes: xlabel='sex', ylabel='G3'>

# %% [raw]
# # Insights -- Both Urban males and females are getting more marks

# %%
num_col=['age','traveltime','studytime','absences','G1','G2','G3']
sns.boxplot(data=df[num_col], palette='Set3')
# Out:
# <Axes: >

# %% [raw]
# # Insights -- Median age is 17
# # median marks for g1 and g3 are same
# # There are some outliers

# %%
corr=df.corr(numeric_only=True)

# %%
plt.figure(figsize=(12,10))
sns.heatmap(corr, annot=True, cmap='coolwarm',fmt='.2f')
# Out:
# <Axes: >

# %% [raw]
# # Insights -- Strong positive correlations , strong negative correlations

# %% [markdown]
# ## Outlier Detection

# %% [raw]
# -- To detect Outlier - Distibution, boxplot, violinplot

# %%
stu_grd_df=df.copy()
stu_grd_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        4   0  11  11
# 1    ...      5        3      3     1     1      3        2   9  11  11
# 2    ...      4        3      2     2     3      3        6  12  13  12
# 3    ...      3        2      2     1     1      5        0  14  14  14
# 4    ...      4        3      2     1     2      5        0  11  13  13
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [649 rows x 33 columns]

# %%
# Multiple columns
stu_grd_df=stu_grd_df.drop(['G1','G2','G3'],axis=1)

# %%
stu_grd_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... higher internet  romantic  famrel  freetime goout Dalc Walc health  \
# 0    ...    yes       no        no       4         3     4    1    1      3
# 1    ...    yes      yes        no       5         3     3    1    1      3
# 2    ...    yes      yes        no       4         3     2    2    3      3
# 3    ...    yes      yes       yes       3         2     2    1    1      5
# 4    ...    yes       no        no       4         3     2    1    2      5
# ..   ...    ...      ...       ...     ...       ...   ...  ...  ...    ...
# 644  ...    yes      yes        no       5         4     2    1    2      5
# 645  ...    yes      yes        no       4         3     4    1    1      1
# 646  ...    yes       no        no       1         1     1    1    1      5
# 647  ...    yes      yes        no       2         4     5    3    4      2
# 648  ...    yes      yes        no       4         4     1    3    4      5
#
#     absences
# 0          4
# 1          2
# 2          6
# 3          0
# 4          0
# ..       ...
# 644        4
# 645        4
# 646        6
# 647        6
# 648        4
#
# [649 rows x 30 columns]

# %%
# Q1-1.5*IQR
# Q3-1.5*IQR

# %%
def detect_out(columns):
    outler_indices=[]
    for column in columns:
        Q1=stu_grd_df[column].quantile(0.25)
        Q3=stu_grd_df[column].quantile(0.75)
        IQR=Q3-Q1

        # Mask is a boolean condition 
        mask = (stu_grd_df[column] >= (Q1-1.5*IQR)) & (stu_grd_df[column] <= (Q3+1.5*IQR))
        mask=mask.to_numpy() # bool to nupy array

        # Find the indices of value that do not satisfy the mask condition -- that is a outlier 
        false_indices=np.argwhere(~mask)
        outler_indices.append(false_indices)
    return np.unique(np.concatenate(outler_indices).ravel())  
# (np.concatenate(outler_indices) -- combine all the outlier index arrays into a single array
# So each column will have one array
# .ravel-- flattens the multi-dimensional array into 1 D array

# %%
num_cols=['age','absences']
detect_out(num_cols)
# Out:
# array([ 40, 103, 150, 155, 161, 197, 206, 211, 212, 217, 230, 253, 254,
#        256, 263, 279, 311, 325, 326, 397, 405, 413])

# %%
stu_grd_df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences'],
#       dtype='object')

# %%
# Considering absences AS a target variable 
x,y=stu_grd_df.iloc[:,:-1],stu_grd_df.iloc[:,-1]

# %%
x
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... nursery higher  internet  romantic  famrel freetime goout Dalc Walc  \
# 0    ...     yes    yes        no        no       4        3     4    1    1
# 1    ...      no    yes       yes        no       5        3     3    1    1
# 2    ...     yes    yes       yes        no       4        3     2    2    3
# 3    ...     yes    yes       yes       yes       3        2     2    1    1
# 4    ...     yes    yes        no        no       4        3     2    1    2
# ..   ...     ...    ...       ...       ...     ...      ...   ...  ...  ...
# 644  ...      no    yes       yes        no       5        4     2    1    2
# 645  ...     yes    yes       yes        no       4        3     4    1    1
# 646  ...     yes    yes        no        no       1        1     1    1    1
# 647  ...      no    yes       yes        no       2        4     5    3    4
# 648  ...      no    yes       yes        no       4        4     1    3    4
#
#     health
# 0        3
# 1        3
# 2        3
# 3        5
# 4        5
# ..     ...
# 644      5
# 645      1
# 646      5
# 647      2
# 648      5
#
# [649 rows x 29 columns]

# %%
y
# Out:
# 0      4
# 1      2
# 2      6
# 3      0
# 4      0
#       ..
# 644    4
# 645    4
# 646    6
# 647    6
# 648    4
# Name: absences, Length: 649, dtype: int64

# %% [markdown]
# ## Train_split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x, y, test_size=0.25, random_state=1)

# %%
x_train.shape
# Out:
# (486, 29)

# %%
x_test.shape
# Out:
# (163, 29)

# %%
y_train.shape
# Out:
# (486,)

# %%
y_test.shape
# Out:
# (163,)

# %%
# Data Encoding
# Scaling

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler # boyh are the data transformation 
from sklearn.compose import ColumnTransformer

# %%
cat_features=x.select_dtypes(include='object').columns
num_features=x.select_dtypes(exclude='object').columns

# %%
cat_features
# Out:
# Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='object')

# %%
num_features
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health'],
#       dtype='object')

# %%
numeric_transf=StandardScaler()
oh_transf=OneHotEncoder(drop='first')
preproc=ColumnTransformer(
    [
        ('OneHotEncoder',oh_transf,cat_features),('StandardScaler',numeric_transf,num_features)
    ]
)

# %%
preproc
# Out:
# ColumnTransformer(transformers=[('OneHotEncoder', OneHotEncoder(drop='first'),
#                                  Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='object')),
#                                 ('StandardScaler', StandardScaler(),
#                                  Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health'],
#       dtype='object'))])

# %%
oh_transf
# Out:
# OneHotEncoder(drop='first')
